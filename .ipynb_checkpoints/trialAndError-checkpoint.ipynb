# %%
# Import required libraries
import pandas as pd

# %%
# Load the split data
splitData = pd.read_csv('splitKinectData.csv')

# %%
splitData.head()
# Out:
#    Unnamed: 0 face_engaged face_glasses face_happy face_lefteyeclosed  \
# 0           0           no      unknown    unknown            unknown
# 1           1           no      unknown    unknown            unknown
# 2           2           no      unknown    unknown            unknown
# 3           3           no          yes         no                yes
# 4           4           no          yes         no                yes
#
#   face_lookingaway face_mouthmoved face_mouthopen  face_pitch  \
# 0              yes         unknown        unknown          30
# 1              yes         unknown        unknown          30
# 2              yes         unknown        unknown          30
# 3              yes             yes             no          25
# 4              yes             yes             no          25
#
#   face_righteyeclosed     ...      SpineShoulderZ  WristLeftX  WristLeftY  \
# 0             unknown     ...            1.401305   -0.032113   -0.029377
# ...
